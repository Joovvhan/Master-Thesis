# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Joovvhan/Master-Thesis/blob/master/Prediction_Test_ResNet50_A3F1P3_vs_A3F5P3.ipynb)

# %%
# Import library
import os
import glob

# %%
# Mount google drive

from google.colab import drive

drive.mount('/content/gdrive')
os.listdir('gdrive/My Drive/Colab')
# Out:
# Mounted at /content/gdrive
# ['Model', 'Data']

# %%
from keras.models import load_model

# Set model path

modelPath = 'gdrive/My Drive/Colab/Model'

dataPath = 'gdrive/My Drive/Colab/Data'

modelList = glob.glob(modelPath + '/*h5')

print(modelList)

model = load_model(modelList[0])
# Out:
# Using TensorFlow backend.
# ['gdrive/My Drive/Colab/Model/A3F1P3 vs A3F5P3 ResNet50 10-06 05:30:50.h5']

# %%
dataPath = 'gdrive/My Drive/Colab/Data'

foldersTest = ['A3F2P3', 'A3F3P3', 'A3F4P3']

for i in range(len(foldersTest)):
    print(glob.glob(dataPath + '/' + foldersTest[i] + '/*.wav'))
# Out:
# ['gdrive/My Drive/Colab/Data/A3F2P3/A3.490899_F0.538054_P2.175561_H374.957714.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.497513_F0.755409_P1.745498_H367.602924.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.496333_F0.402069_P1.626650_H386.024560.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.499085_F0.532396_P1.933570_H333.070234.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.496042_F0.713105_P1.984053_H379.495313.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.494009_F0.543420_P2.101778_H366.506322.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.493389_F0.748132_P1.849627_H377.392407.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.490139_F0.571216_P2.382107_H379.238975.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.489712_F0.518395_P1.714594_H388.362190.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.487535_F0.707017_P1.855228_H403.438006.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.487289_F0.479435_P1.800694_H364.534037.wav', 'gdrive/My Drive/Colab/Data/A3F2P3/A3.483720_F0.615356_P2.053118_H368.590574.wav', '
# ...
