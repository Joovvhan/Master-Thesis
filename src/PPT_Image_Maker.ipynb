# %% [markdown]
# <a href="https://colab.research.google.com/github/Joovvhan/Master-Thesis/blob/master/src/PPT_Image_Maker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import scipy.io.wavfile
import numpy as np
import glob
import scipy.io.wavfile as wf

x = glob.glob('''D:/0_Joowhan's Paper/Synthesized/Total/A3F3P3/A2.503786_F1.078928_P2.372837_H360.032644.wav''')
print(x)

nsc = 1470
nov = nsc/2
nff = nsc 
imgSize = 224

fs, dataInt16 = wf.read('''D:\\0_Joowhan's Paper\\Synthesized\\A2.519309_F1.125802_P2.205229_H382.397819.wav''')
dataFloat = dataInt16 / (2 ** 15)
Pxx, _, _, _ = plt.specgram(dataFloat, NFFT=nff, Fs=fs, noverlap=nov, \
                                   window=np.hamming(nsc), cmap='viridis')
# fig = plt.gcf()
# fig.set_size_inches(10, 10)
# plt.gca().get_xaxis().set_visible(False)
# plt.gca().get_yaxis().set_visible(False)

# plt.colorbar()

fig = plt.gcf()
fig.set_size_inches(12, 10)
# plt.gca().get_xaxis().set_visible(False)
# plt.gca().get_yaxis().set_visible(False)

cb = plt.colorbar()

cb.ax.set_yticklabels(cb.ax.get_yticklabels(), fontsize=tickFont)

plt.clim((-80, -50))
plt.xlabel('Time(s)', fontsize=labelFont, labelpad = 24)
plt.xlim([0, 3])
plt.xticks([1 ,2 , 3], fontsize=tickFont)

plt.ylabel('Frequency(Hz)', fontsize=labelFont, labelpad = 24)
plt.xlim([0, 3])
plt.yticks(fontsize=tickFont)

plt.ylim((0, 6400))
# plt.ylim((2000, 6000))

plt.show()


fs, dataInt16 = wf.read('''D:\\0_Joowhan's Paper\\Synthesized\\P0.426401_N3_H380.160817.wav''')
dataFloat = dataInt16 / (2 ** 15)
Pxx, _, _, _ = plt.specgram(dataFloat, NFFT=nff, Fs=fs, noverlap=nov, \
                                   window=np.hamming(nsc), cmap='viridis')
# fig = plt.gcf()
# fig.set_size_inches(10, 10)
# plt.gca().get_xaxis().set_visible(False)
# plt.gca().get_yaxis().set_visible(False)

# plt.colorbar()

fig = plt.gcf()
fig.set_size_inches(12, 10)
# plt.gca().get_xaxis().set_visible(False)
# plt.gca().get_yaxis().set_visible(False)

cb = plt.colorbar()

cb.ax.set_yticklabels(cb.ax.get_yticklabels(), fontsize=tickFont)

plt.clim((-80, -50))
plt.xlabel('Time(s)', fontsize=labelFont, labelpad = 24)
plt.xlim([0, 3])
plt.xticks([1 ,2 , 3], fontsize=tickFont)

plt.ylabel('Frequency(Hz)', fontsize=labelFont, labelpad = 24)
plt.xlim([0, 3])
plt.yticks(fontsize=tickFont)

plt.ylim((0, 6400))
# plt.ylim((2000, 6000))

plt.show()
# Out:
# []

# %%
import matplotlib.pyplot as plt
import scipy.io.wavfile
import numpy as np
import glob
import scipy.io.wavfile as wf

x = glob.glob('''D:/0_Joowhan's Paper/Real Data/Mando/20171115-133323_IKCK171110A0214-TILTUP.wav''')
print(x)

labelFont = 36
tickFont = 24

nsc = int(1470 / 3)
nov = nsc/2
nff = nsc 
imgSize = 224

fs, dataInt16 = wf.read('''D:/0_Joowhan's Paper/Real Data/Mando/20171115-133323_IKCK171110A0214-TILTUP.wav''')
dataFloat = dataInt16 / (2 ** 15)
Pxx, _, _, _ = plt.specgram(dataFloat[:, 1], NFFT=nff, Fs=fs, noverlap=nov, \
                                   window=np.hamming(nsc), cmap='viridis')
fig = plt.gcf()
fig.set_size_inches(12, 10)
# plt.gca().get_xaxis().set_visible(False)
# plt.gca().get_yaxis().set_visible(False)

cb = plt.colorbar()

cb.ax.set_yticklabels(cb.ax.get_yticklabels(), fontsize=tickFont)

plt.clim((-80, -50))

# plt.ylim((2000, 6000))

plt.xlabel('Time(s)', fontsize=labelFont, labelpad = 24)
plt.xlim([0, 3])
plt.xticks([1 ,2 , 3], fontsize=tickFont)

plt.ylabel('Frequency(Hz)', fontsize=labelFont, labelpad = 24)
plt.xlim([0, 3])
plt.yticks(fontsize=tickFont)


plt.show()

fs, dataInt16 = wf.read('''D:/0_Joowhan's Paper/Real Data/Mando/20180716-071024_IKCK180712A0180-TELEOUT.wav''')
dataFloat = dataInt16 / (2 ** 15)
Pxx, _, _, _ = plt.specgram(dataFloat[int(0.5 * fs): int(3.6 *fs) + 1], NFFT=nff, Fs=fs, noverlap=nov, \
                                   window=np.hamming(nsc), cmap='viridis')
fig = plt.gcf()
fig.set_size_inches(12, 10)
# plt.gca().get_xaxis().set_visible(False)
# plt.gca().get_yaxis().set_visible(False)

cb = plt.colorbar()

cb.ax.set_yticklabels(cb.ax.get_yticklabels(), fontsize=tickFont)

plt.clim((-80, -50))
plt.xlabel('Time(s)', fontsize=labelFont, labelpad = 24)
plt.xlim([0, 3])
plt.xticks([1 ,2 , 3], fontsize=tickFont)

plt.ylabel('Frequency(Hz)', fontsize=labelFont, labelpad = 24)
plt.xlim([0, 3])
plt.yticks(fontsize=tickFont)


# plt.ylim((2000, 6000))

plt.show()
# Out:
# ["D:/0_Joowhan's Paper/Real Data/Mando/20171115-133323_IKCK171110A0214-TILTUP.wav"]

# %%
x = glob.glob('''D:/0_Joowhan's Paper/Synthesized/Total/A3F3P3/A2.503786_F1.078928_P2.372837_H360.032644.wav''')
print(x)

nsc = 1470
nov = nsc/2
nff = nsc 
imgSize = 224

fs, dataInt16 = wf.read('''D:\\0_Joowhan's Paper\\Go.wav''')
dataFloat = dataInt16 / (2 ** 15)
Pxx, _, _, _ = plt.specgram(dataFloat, NFFT=nff, Fs=fs, noverlap=nov, \
                                   window=np.hamming(nsc), cmap='viridis')
fig = plt.gcf()
fig.set_size_inches(10, 10)
# plt.gca().get_xaxis().set_visible(False)
# plt.gca().get_yaxis().set_visible(False)

# plt.colorbar()

plt.clim((-80, -60))

plt.ylim((0, 6000))

plt.xticks(fontsize=36)
plt.xlabel('Time(s)', fontsize=36, labelpad = 24)

plt.yticks(fontsize=36)
plt.ylabel('Freqeuncy(Hz)', fontsize=36, labelpad = 24)


plt.show()
# Out:
# ["D:/0_Joowhan's Paper/Synthesized/Total/A3F3P3/A2.503786_F1.078928_P2.372837_H360.032644.wav"]

# %%
x = glob.glob('''D:/0_Joowhan's Paper/Synthesized/Total/A3F3P3/A2.503786_F1.078928_P2.372837_H360.032644.wav''')
print(x)

nsc = 1470
nov = nsc/2
nff = nsc 
imgSize = 224

fs, dataInt16 = wf.read('''D:\\0_Joowhan's Paper\\Synthesized\\Total\\A3F3P3\\A2.503786_F1.078928_P2.372837_H360.032644.wav''')
dataFloat = dataInt16 / (2 ** 15)
Pxx, _, _, _ = plt.specgram(dataFloat, NFFT=nff, Fs=fs, noverlap=nov, \
                                   window=np.hamming(nsc), cmap='viridis')
fig = plt.gcf()
fig.set_size_inches(10, 10)
# plt.gca().get_xaxis().set_visible(False)
# plt.gca().get_yaxis().set_visible(False)

# plt.colorbar()

plt.clim((-80, -60))

plt.ylim((0, 6000))

# for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
#              ax.get_xticklabels() + ax.get_yticklabels()):
#     item.set_fontsize(20)
# plt.xticks(fontsize=14, rotation=90)


plt.xticks(fontsize=36)
plt.xlabel('Time(s)', fontsize=36, labelpad = 24)

plt.yticks(fontsize=36)
plt.ylabel('Freqeuncy(Hz)', fontsize=36, labelpad = 24)



plt.show()
# Out:
# ["D:/0_Joowhan's Paper/Synthesized/Total/A3F3P3/A2.503786_F1.078928_P2.372837_H360.032644.wav"]
